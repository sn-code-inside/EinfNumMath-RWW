# %% [markdown]
# # Python implementation of the algorithms presented in *"Introduction to Numerical Mathematics - Theory, Practice and Numerous Examples"* by T. Richter, H. von Wahl and T. Wick
#
# ## Chapter 1: Introduction
# - [1.2 Definition of an Algorithm](1.2_Definition_of_an_Algorithm.ipynb)
# ## Chapter 3: Linear Systems of Equations
# - [3.2 The Gaussian Elimination Method and the LU Decomposition](3.2_LU_Decomposition.ipynb)
# - [3.3 The Cholesky factorization for symmetric positive definite matrices](3.3_Cholesky.ipynb)
# - [3.4 Sparse matrices](3.4_Cuthill-McKee.ipynb)
# - [3.6 Iterative Refinement](3.6_Iterative_Refinement.ipynb)
# - [3.7 Iterative Methods for Solving Linear Systems](3.7_Iterative.ipynb)
# ## Chapter 4: Orthogonalization Methods and QR Factorization
# - [4.2 Gram-Schmidt Orthogonalization](4.2_Gram-Schmidt.ipynb)
# - [4.3 Householder Transformations](4.3_Householder.ipynb)
# - [4.4 Givens Rotations](4.4_Givens.ipynb)
# - [4.5 Overdetermined Systems](4.5_Least_Squares.ipynb)
# ## Chapter 5: The Eigenvalue Problem
# - [5.3 Iterative Methods ](5.3_Eigen_Iterative.ipynb)
# - [5.4 Factorization methods](5.4_Eigen_Factorisation.ipynb)
# - [5.5 The QR Iteration for Matrices in Hessenberg Form](5.5_QR_Hessenberg.ipynb)
# ## Chapter 6: Krylov Subspace Methods
# - [6.2 The Conjugate Gradient Method](6.2_CG_method.ipynb)
# - [6.5 The GMRES Method](6.5_GMRES.ipynb)
# ## Chapter 8: Root Finding Problems
# - [8.1 Stability and Conditioning](8.1_Roots.ipynb)
# - [8.2 The Bisection Method](8.2_Bisection.ipynb)
# - [8.3 Newton's method](8.3_Newton.ipynb)
# - [8.4 Solving Nonlinear Systems](8.4_Newton_Rn.ipynb)
# ## Chapter 9 Interpolation and Approximation
# - [9.1 Polynomial Interpolation](9.1_Polynomialinterpolation.ipynb)
# - [9.3 Numerical Differentiation](9.3_Differentiation.ipynb)
# - [9.4 Richardson Extrapolation](9.4_Richardson.ipynb)
